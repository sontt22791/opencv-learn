# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('C:/data-software-engineer/opencv/resources/Photos/cat.jpg')
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
cv2.imshow("out", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
